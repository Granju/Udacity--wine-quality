# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('winequality.csv')

# %%
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
columns = df.columns

# %%
columns = [column.replace(' ', '_') for column in columns]
df.columns = columns

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.hist(figsize=(20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'fixed_acidity'}>,
#         <AxesSubplot:title={'center':'volatile_acidity'}>,
#         <AxesSubplot:title={'center':'citric_acid'}>],
#        [<AxesSubplot:title={'center':'residual_sugar'}>,
#         <AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free_sulfur_dioxide'}>],
#        [<AxesSubplot:title={'center':'total_sulfur_dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>,
#         <AxesSubplot:title={'center':'pH'}>],
#        [<AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>]], dtype=object)

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
fig, ax = plt.subplots(figsize=(10, 8))
cormat = df.corr()
round(cormat,2)
sns.heatmap(cormat, annot=True)
plt.show()

# %%
df_by_type = df.groupby('type').mean().reset_index().transpose()

# %%
df_by_type
# Out:
#                               0           1
# type                        red       white
# fixed_acidity          8.322104    6.855532
# volatile_acidity       0.527738    0.278252
# citric_acid            0.271145     0.33425
# residual_sugar         2.538806     6.39325
# chlorides              0.087467    0.045778
# free_sulfur_dioxide   15.874922   35.308085
# total_sulfur_dioxide  46.467792  138.360657
# density                0.996747    0.994027
# pH                     3.310864    3.188203
# sulphates              0.658078    0.489835
# alcohol               10.422983   10.514267
# quality                5.636023    5.877909

# %%
df_by_type.columns=['red','white']

# %%
df_by_type.drop(index=df_by_type.index[0], axis=0, inplace=True)

# %%
df_by_type['red'] = pd.to_numeric(df_by_type['red'],errors='coerce')

# %%
df_by_type['white'] = pd.to_numeric(df_by_type['white'],errors='coerce')

# %%
df_by_type
# Out:
#                             red       white
# fixed_acidity          8.322104    6.855532
# volatile_acidity       0.527738    0.278252
# citric_acid            0.271145    0.334250
# residual_sugar         2.538806    6.393250
# chlorides              0.087467    0.045778
# free_sulfur_dioxide   15.874922   35.308085
# total_sulfur_dioxide  46.467792  138.360657
# density                0.996747    0.994027
# pH                     3.310864    3.188203
# sulphates              0.658078    0.489835
# alcohol               10.422983   10.514267
# quality                5.636023    5.877909

# %%
df_by_type['diff_perc'] = (df_by_type['white'] - df_by_type['red']) / df_by_type['white'] *100

# %%
df_by_type.sort_values(by='diff_perc', ascending=False).style.bar(subset=['diff_perc'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style type="text/css">
# #T_b1664_row0_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 100.0%, transparent 100.0%);
# }
# #T_b1664_row1_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 96.1%, transparent 96.1%);
# }
# #T_b1664_row2_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 92.8%, transparent 92.8%);
# }
# #T_b1664_row3_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 69.8%, transparent 69.8%);
# }
# #T_b1664_row4_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 60.4%, transparent 60.4%);
# }
# #T_b1664_row5_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.8%, #5fba7d 57.8%, #5fba7d 58.4%, transparent 58.4%);
# }
# #T_b1664_row6_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 57.7%, #d65f5f 57.7%, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_b1664_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 55.4%, #d65f5f 55.4%, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_b1664_row8_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 44.2%, #d65f5f 44.2%, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_b1664_row9_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 36.0%, #d65f5f 36.0%, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_b1664_row10_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.9%, #d65f5f 0.9%, #d65f5f 57.8%, transparent 57.8%);
# }
# #T_b1664_row11_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 57.8%, transparent 57.8%);
# }
# </style>
# <table id="T_b1664_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >red</th>
#       <th class="col_heading level0 col1" >white</th>
#       <th class="col_heading level0 col2" >diff_perc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1664_level0_row0" class="row_heading level0 row0" >total_sulfur_dioxide</th>
#       <td id="T_b1664_row0_col0" class="data row0 col0" >46.467792</td>
#       <td id="T_b1664_row0_col1" class="data row0 col1" >138.360657</td>
#       <td id="T_b1664_row0_col2" class="data row0 col2" >66.415459</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row1" class="row_heading level0 row1" >residual_sugar</th>
#       <td id="T_b1664_row1_col0" class="data row1 col0" >2.538806</td>
#       <td id="T_b1664_row1_col1" class="data row1 col1" >6.393250</td>
#       <td id="T_b1664_row1_col2" class="data row1 col2" >60.289279</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row2" class="row_heading level0 row2" >free_sulfur_dioxide</th>
#       <td id="T_b1664_row2_col0" class="data row2 col0" >15.874922</td>
#       <td id="T_b1664_row2_col1" class="data row2 col1" >35.308085</td>
#       <td id="T_b1664_row2_col2" class="data row2 col2" >55.038848</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row3" class="row_heading level0 row3" >citric_acid</th>
#       <td id="T_b1664_row3_col0" class="data row3 col0" >0.271145</td>
#       <td id="T_b1664_row3_col1" class="data row3 col1" >0.334250</td>
#       <td id="T_b1664_row3_col2" class="data row3 col2" >18.879626</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row4" class="row_heading level0 row4" >quality</th>
#       <td id="T_b1664_row4_col0" class="data row4 col0" >5.636023</td>
#       <td id="T_b1664_row4_col1" class="data row4 col1" >5.877909</td>
#       <td id="T_b1664_row4_col2" class="data row4 col2" >4.115185</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row5" class="row_heading level0 row5" >alcohol</th>
#       <td id="T_b1664_row5_col0" class="data row5 col0" >10.422983</td>
#       <td id="T_b1664_row5_col1" class="data row5 col1" >10.514267</td>
#       <td id="T_b1664_row5_col2" class="data row5 col2" >0.868191</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row6" class="row_heading level0 row6" >density</th>
#       <td id="T_b1664_row6_col0" class="data row6 col0" >0.996747</td>
#       <td id="T_b1664_row6_col1" class="data row6 col1" >0.994027</td>
#       <td id="T_b1664_row6_col2" class="data row6 col2" >-0.273564</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row7" class="row_heading level0 row7" >pH</th>
#       <td id="T_b1664_row7_col0" class="data row7 col0" >3.310864</td>
#       <td id="T_b1664_row7_col1" class="data row7 col1" >3.188203</td>
#       <td id="T_b1664_row7_col2" class="data row7 col2" >-3.847349</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row8" class="row_heading level0 row8" >fixed_acidity</th>
#       <td id="T_b1664_row8_col0" class="data row8 col0" >8.322104</td>
#       <td id="T_b1664_row8_col1" class="data row8 col1" >6.855532</td>
#       <td id="T_b1664_row8_col2" class="data row8 col2" >-21.392538</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row9" class="row_heading level0 row9" >sulphates</th>
#       <td id="T_b1664_row9_col0" class="data row9 col0" >0.658078</td>
#       <td id="T_b1664_row9_col1" class="data row9 col1" >0.489835</td>
#       <td id="T_b1664_row9_col2" class="data row9 col2" >-34.346921</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row10" class="row_heading level0 row10" >volatile_acidity</th>
#       <td id="T_b1664_row10_col0" class="data row10 col0" >0.527738</td>
#       <td id="T_b1664_row10_col1" class="data row10 col1" >0.278252</td>
#       <td id="T_b1664_row10_col2" class="data row10 col2" >-89.661890</td>
#     </tr>
#     <tr>
#       <th id="T_b1664_level0_row11" class="row_heading level0 row11" >chlorides</th>
#       <td id="T_b1664_row11_col0" class="data row11 col0" >0.087467</td>
#       <td id="T_b1664_row11_col1" class="data row11 col1" >0.045778</td>
#       <td id="T_b1664_row11_col2" class="data row11 col2" >-91.065130</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[['red', 'white']] = pd.get_dummies(df['type'])
df.drop('type', axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# fixed_acidity           10
# volatile_acidity         8
# citric_acid              3
# residual_sugar           2
# chlorides                2
# free_sulfur_dioxide      0
# total_sulfur_dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# red                      0
# white                    0
# dtype: int64

# %%
df= df.dropna()

# %%
df.isna().sum()
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# red                     0
# white                   0
# dtype: int64

# %%
for column in df.loc[:, ~df.columns.isin(['red', 'white'])]:
    plt.figure()
    df.boxplot([column])

# %%
df.quality.value_counts()
# Out:
# 6    2820
# 5    2128
# 7    1074
# 4     214
# 8     192
# 3      30
# 9       5
# Name: quality, dtype: int64

# %%
map = {3 : 'poor', 4 : 'poor', 5 : 'average', 6 : 'good', 7 :'good', 8 : 'good', 9 : 'good'}
df['quality'] = df['quality'].map(map)

# %%
df.quality.value_counts()
# Out:
# good       4091
# average    2128
# poor        244
# Name: quality, dtype: int64

# %%
y = df.quality
X = df.loc[:, df.columns != 'quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=10)

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      average       0.76      0.71      0.74       537
#         good       0.85      0.90      0.87      1031
#         poor       0.62      0.17      0.26        48
#
#     accuracy                           0.82      1616
#    macro avg       0.74      0.59      0.62      1616
# weighted avg       0.81      0.82      0.81      1616
